# %%
import cv2
import numpy as np
import pandas as pd
import os
import time
import shutil

# %%
def extract_frames(video_path, output_folder, duration=30):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    video_fps = cap.get(cv2.CAP_PROP_FPS)
    end_frame = min(int(duration * video_fps), total_frames)
    frame_index = 0
    while cap.isOpened() and frame_index < end_frame:
        ret, frame = cap.read()
        if not ret:
            break
        output_path = f"{output_folder}/frame_{frame_index:05d}.jpg"
        cv2.imwrite(output_path, frame)
        frame_index += 1
    cap.release()
    cv2.destroyAllWindows()

# %%
video_path = "input_video.mp4"
output_folder = "./output_frames"
duration = 30
extract_frames(video_path, output_folder, duration)

# %%
def detect_faces_in_frames(frames_folder, output_folder):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    total_time = 0
    frame_count = 0
    for filename in os.listdir(frames_folder):
        if filename.endswith(".jpg"):
            frame_path = os.path.join(frames_folder, filename)
            frame = cv2.imread(frame_path)
            start_time = time.time()
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            for (x, y, w, h) in faces:
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, frame)
            end_time = time.time()
            frame_processing_time = end_time - start_time
            total_time += frame_processing_time
            frame_count += 1
    average_time_per_frame = total_time / frame_count if frame_count > 0 else 0
    print("Average time per frame:", average_time_per_frame, "seconds")

# %%
def detect_faces_in_frames_coloured(frames_folder, output_folder):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    total_time = 0
    frame_count = 0
    for filename in os.listdir(frames_folder):
        if filename.endswith(".jpg"):
            frame_path = os.path.join(frames_folder, filename)
            frame = cv2.imread(frame_path)
            start_time = time.time()
            faces = face_cascade.detectMultiScale(frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            for (x, y, w, h) in faces:
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, frame)
            end_time = time.time()
            frame_processing_time = end_time - start_time
            total_time += frame_processing_time
            frame_count += 1
    average_time_per_frame = total_time / frame_count if frame_count > 0 else 0
    print("Average time per frame coloured:", average_time_per_frame, "seconds")

# %%
frames_folder = "output_frames"
output_folder = "output_frames_with_faces"
output_folder_coloured = "output_frames_with_faces_coloured"
detect_faces_in_frames(frames_folder, output_folder)
detect_faces_in_frames_coloured(frames_folder, output_folder_coloured)
# Out:
# Average time per frame: 0.08027088459741755 seconds
# Average time per frame coloured: 0.0893887150436847 seconds

# %%
def frames_to_video(frames_folder, output_video_path, fps=30):
    frame_files = [f for f in os.listdir(frames_folder) if f.endswith('.jpg')]
    frame_files.sort()
    frame_path = os.path.join(frames_folder, frame_files[0])
    frame = cv2.imread(frame_path)
    height, width, _ = frame.shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    for filename in frame_files:
        frame_path = os.path.join(frames_folder, filename)
        frame = cv2.imread(frame_path)
        out.write(frame)
    out.release()
    print(f"Video saved successfully at '{output_video_path}'")

# %%
frames_folder = "output_frames_with_faces"
output_video_path = "output_video.mp4"
frames_to_video(frames_folder, output_video_path)
frames_folder = "output_frames_with_faces_coloured"
output_video_path = "output_video_coloured.mp4"
frames_to_video(frames_folder, output_video_path)
# Out:
# Video saved successfully at 'output_video.mp4'
# Video saved successfully at 'output_video_coloured.mp4'

# %% [markdown]
# We can change the following things in the xml file:
#
# Number of Stages in the Cascade: The cascade classifier in Viola-Jones is a sequence of increasingly complex stages. Each stage filters out a large portion of non-face regions. xml file defines the number of stages. More stages lead to higher accuracy but slower processing time. We can adjust this trade-off by modifying the cascade structure in the xml file.
#
# Minimum Feature Size: This parameter specifies the minimum size of a Haar-like feature considered during detection. A smaller minimum size allows for detecting faces in various scales but requires evaluating more features, impacting speed. The minimum feature size is defined within the xml file.
#
# Search Window Size: The algorithm scans sub-regions of the image (search windows) for faces. A larger search window size covers more area but takes longer to process. The xml file specifies the search window size, and adjusting it can affect detection time.
#
# Boosting Threshold: The AdaBoost algorithm assigns weights to features based on their effectiveness in classifying faces. The boosting threshold determines the minimum weight a weak classifier needs to be included in the final cascade. A lower threshold leads to more features being considered, potentially impacting speed.

# %%
def calculate_iou(box1, box2):
    x1, y1, w1, h1 = box1
    x2, y2, w2, h2 = box2
    x_left = max(x1, x2)
    y_top = max(y1, y2)
    x_right = min(x1 + w1, x2 + w2)
    y_bottom = min(y1 + h1, y2 + h2)
    intersection_area = max(0, x_right - x_left) * max(0, y_bottom - y_top)
    box1_area = w1 * h1
    box2_area = w2 * h2
    iou = intersection_area / float(box1_area + box2_area - intersection_area)
    return iou

# %%
def generate_face_tracks(frames_folder):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    frame_files = [f for f in os.listdir(frames_folder) if f.endswith('.jpg')]
    frame_files.sort()
    tracks = {}
    final_tracks = {}
    frame_number = 0
    main_track_id = 0
    for filename in frame_files:
        frame_path = os.path.join(frames_folder, filename)
        print(frame_path)
        frame = cv2.imread(frame_path)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        for track_id in list(tracks.keys()):
            last_frame_number, last_box = tracks[track_id][-1]
            best_iou = 0
            best_box_index = -1
            for i, (x, y, w, h) in enumerate(faces):
                iou = calculate_iou(last_box, (x, y, w, h))
                if iou > best_iou:
                    best_iou = iou
                    best_box_index = i
            if best_iou > 0.5:
                print("HI")
                print(best_iou)
                x, y, w, h = faces[best_box_index]
                tracks[track_id].append((frame_number, (x, y, w, h)))
            else:
                item_to_move = tracks.pop(track_id)
                final_tracks[track_id] = item_to_move
        for i, (x, y, w, h) in enumerate(faces):
            is_new_track = True
            for track_id in tracks:
                last_frame_number, last_box = tracks[track_id][-1]
                iou = calculate_iou(last_box, (x, y, w, h))
                if iou > 0.5:
                    is_new_track = False
                    break
            if is_new_track:
                print("hi")
                print(main_track_id)
                tracks[main_track_id] = [(frame_number, (x, y, w, h))]
                main_track_id += 1
        frame_number += 1
    final_tracks.update(tracks)
    return final_tracks

# %%
frames_folder = "output_frames"
unique_tracks = generate_face_tracks(frames_folder)
# Out:
# output_frames\frame_00000.jpg
# output_frames\frame_00001.jpg
# hi
# 0
# output_frames\frame_00002.jpg
# HI
# 0.8089648945775134
# output_frames\frame_00003.jpg
# HI
# 0.9130019657399607
# output_frames\frame_00004.jpg
# output_frames\frame_00005.jpg
# output_frames\frame_00006.jpg
# output_frames\frame_00007.jpg
# output_frames\frame_00008.jpg
# hi
# 1
# output_frames\frame_00009.jpg
# hi
# 2
# output_frames\frame_00010.jpg
# output_frames\frame_00011.jpg
# hi
# 3
# output_frames\frame_00012.jpg
# HI
# 0.92340087890625
# hi
# 4
# output_frames\frame_00013.jpg
# HI
# 0.9367640361720122
# output_frames\frame_00014.jpg
# HI
# 0.8925619834710744
# output_frames\frame_00015.jpg
# HI
# 0.8631459398069279
# output_frames\frame_00016.jpg
# HI
# 0.8604090672225118
# hi
# 5
# output_frames\frame_00017.jpg
# HI
# 0.9833333333333333
# output_frames\frame_00018.jpg
# HI
# 0.9672153541424766
# output_frames\frame_00019.jpg
# HI
# 0.8920808440320326
# output_frames\frame_00020.jpg
# HI
# 0.8410987482614742
# output_frames\frame_00021.jpg
# HI
# 0.9262594027809437
# hi
# 6
# output_frames\frame_00022.jpg
# HI
# 0.850820662571745
# output_frames\frame_00023.jpg
# HI
# 0.6622320768662232
# hi
# 7
# output_frames\frame_00024.jpg
# HI
# 0.8168564669637454
# output_frames\frame_00025.jpg
# HI
# 0.818534961154273
# output_frames\frame_00026.jpg
# HI
# 0.8700600158532442
# output_frames\frame_00027.jpg
# HI
# 0.9254401305817885
# hi
# 8
# output_frames\frame_00028.jpg
# HI
# 0.8706450887839964
# output_frames\frame_00029.jpg
# HI
# 0.9129417010366737
# output_frames\frame_00030.jpg
# HI
# 0.911570485213896
# output_frames\frame_00031.jpg
# HI
# 0.8981814099685675
# output_frames\frame_00032.jpg
# HI
# 0.9267033337074868
# output_frames\frame_00033.jpg
# HI
# 0.9251556808835625
# output_frames\frame_00034.jpg
# HI
# 0.984375
# output_frames\frame_00035.jpg
# HI
# 0.9398636443097722
# output_frames\frame_00036.jpg
# HI
# 0.9251209136996679
# output_frames\frame_00037.jpg
# HI
# 0.9251209136996679
# output_frames\frame_00038.jpg
# HI
# 0.9555015266312338
# output_frames\frame_00039.jpg
# HI
# 0.9553378147430786
# output_frames\frame_00040.jpg
# HI
# 0.9267451069125466
# output_frames\frame_00041.jpg
# HI
# 0.9407407407407408
# output_frames\frame_00042.jpg
# HI
# 0.9262594027809437
# output_frames\frame_00043.jpg
# HI
# 0.9115008392660763
# output_frames\frame_00044.jpg
# HI
# 0.9253191861481956
# output_frames\frame_00045.jpg
# HI
# 0.9108985946702431
# output_frames\frame_00046.jpg
# HI
# 0.9393379063525201
# output_frames\frame_00047.jpg
# HI
# 0.9110583878247787
# output_frames\frame_00048.jpg
# HI
# 0.9253191861481956
# output_frames\frame_00049.jpg
# output_frames\frame_00050.jpg
# output_frames\frame_00051.jpg
# output_frames\frame_00052.jpg
# output_frames\frame_00053.jpg
# output_frames\frame_00054.jpg
# output_frames\frame_00055.jpg
# output_frames\frame_00056.jpg
# output_frames\frame_00057.jpg
# output_frames\frame_00058.jpg
# output_frames\frame_00059.jpg
# output_frames\frame_00060.jpg
# output_frames\frame_00061.jpg
# output_frames\frame_00062.jpg
# output_frames\frame_00063.jpg
# output_frames\frame_00064.jpg
# output_frames\frame_00065.jpg
# output_frames\frame_00066.jpg
# output_frames\frame_00067.jpg
# output_frames\frame_00068.jpg
# output_frames\frame_00069.jpg
# output_frames\frame_00070.jpg
# output_frames\frame_00071.jpg
# output_frames\frame_00072.jpg
# output_frames\frame_00073.jpg
# output_frames\frame_00074.jpg
# output_frames\frame_00075.jpg
# output_frames\frame_00076.jpg
# output_frames\frame_00077.jpg
# output_frames\frame_00078.jpg
# hi
# 9
# output_frames\frame_00079.jpg
# HI
# 0.9411236459561093
# output_frames\frame_00080.jpg
# HI
# 0.8998037505451374
# output_frames\frame_00081.jpg
# HI
# 0.927485315913707
# hi
# 10
# output_frames\frame_00082.jpg
# HI
# 0.9269556496545576
# HI
# 0.7795748751831146
# output_frames\frame_00083.jpg
# HI
# 0.9127871061941933
# HI
# 0.816407673701998
# output_frames\frame_00084.jpg
# HI
# 0.9267991467385203
# HI
# 0.9053057250908002
# output_frames\frame_00085.jpg
# HI
# 0.9411764705882353
# HI
# 0.9159929835265406
# output_frames\frame_00086.jpg
# HI
# 0.9125821121778676
# HI
# 0.9167106155352972
# output_frames\frame_00087.jpg
# HI
# 0.9543177480916031
# HI
# 0.8751621384750219
# output_frames\frame_00088.jpg
# HI
# 0.9541411227310975
# HI
# 0.8899094564115975
# hi
# 11
# output_frames\frame_00089.jpg
# HI
# 0.95367431640625
# HI
# 0.9234488821904044
# HI
# 0.629614926558158
# output_frames\frame_00090.jpg
# HI
# 0.9841269841269841
# HI
# 0.9777160532794646
# HI
# 0.685637342908438
# output_frames\frame_00091.jpg
# HI
# 0.9383451184716537
# HI
# 0.9452964917727413
# HI
# 0.7628797886393659
# output_frames\frame_00092.jpg
# HI
# 0.9686894569089431
# HI
# 0.9148763558787296
# HI
# 0.7992148065058889
# output_frames\frame_00093.jpg
# HI
# 1.0
# HI
# 0.9045558360379853
# output_frames\frame_00094.jpg
# HI
# 0.9685059208868733
# HI
# 0.913752625725936
# output_frames\frame_00095.jpg
# HI
# 0.9533139066278132
# HI
# 0.9029451969678141
# output_frames\frame_00096.jpg
# HI
# 0.968751937503875
# HI
# 0.9336420245888551
# output_frames\frame_00097.jpg
# HI
# 0.952576
# HI
# 0.9021457350782397
# output_frames\frame_00098.jpg
# HI
# 0.9375157470395565
# HI
# 0.8416205115439667
# output_frames\frame_00099.jpg
# HI
# 0.922209624590577
# HI
# 0.8568606442108083
# output_frames\frame_00100.jpg
# HI
# 0.9365121354407777
# HI
# 0.8875123379054491
# output_frames\frame_00101.jpg
# HI
# 0.9835393757257018
# HI
# 0.9091064645289346
# output_frames\frame_00102.jpg
# HI
# 0.9674141318338866
# HI
# 0.9177709203122164
# output_frames\frame_00103.jpg
# HI
# 0.9510279352503245
# HI
# 0.9289757166331933
# output_frames\frame_00104.jpg
# HI
# 0.9831226659006033
# HI
# 0.9529072047342341
# output_frames\frame_00105.jpg
# HI
# 0.9663165519739225
# HI
# 0.9643578643578643
# output_frames\frame_00106.jpg
# HI
# 0.918779962481762
# HI
# 0.963749256395003
# hi
# 12
# output_frames\frame_00107.jpg
# HI
# 0.9017018572134736
# HI
# 0.95092781914278
# output_frames\frame_00108.jpg
# HI
# 0.8860849729113203
# HI
# 0.9153780402517678
# output_frames\frame_00109.jpg
# HI
# 0.9665978206680436
# HI
# 0.8816502131909499
# output_frames\frame_00110.jpg
# HI
# 0.8626827717736809
# HI
# 0.8665570351355687
# output_frames\frame_00111.jpg
# HI
# 0.8273504273504273
# HI
# 0.7235117211597779
# output_frames\frame_00112.jpg
# HI
# 0.8546265716437801
# HI
# 0.6263617399366453
# output_frames\frame_00113.jpg
# HI
# 0.884444694118308
# HI
# 0.6803713527851459
# output_frames\frame_00114.jpg
# HI
# 0.9405247143923302
# HI
# 0.7538058042077656
# output_frames\frame_00115.jpg
# HI
# 0.8227728983688833
# HI
# 0.8075025303643725
# output_frames\frame_00116.jpg
# HI
# 0.8042539049518113
# output_frames\frame_00117.jpg
# HI
# 0.8442982456140351
# output_frames\frame_00118.jpg
# HI
# 0.8748346123313046
# output_frames\frame_00119.jpg
# HI
# 0.7801507537688442
# output_frames\frame_00120.jpg
# HI
# 0.807508235440363
# output_frames\frame_00121.jpg
# HI
# 0.7737173155897489
# output_frames\frame_00122.jpg
# HI
# 0.8192620387742339
# output_frames\frame_00123.jpg
# HI
# 0.8222470134337377
# output_frames\frame_00124.jpg
# HI
# 0.8213934771419213
# output_frames\frame_00125.jpg
# HI
# 0.7648040033361134
# output_frames\frame_00126.jpg
# hi
# 13
# output_frames\frame_00127.jpg
# output_frames\frame_00128.jpg
# hi
# 14
# output_frames\frame_00129.jpg
# HI
# 0.5944602272727273
# output_frames\frame_00130.jpg
# HI
# 0.6641957005189029
# output_frames\frame_00131.jpg
# output_frames\frame_00132.jpg
# hi
# 15
# hi
# 16
# output_frames\frame_00133.jpg
# HI
# 0.9523809523809523
# output_frames\frame_00134.jpg
# output_frames\frame_00135.jpg
# hi
# 17
# output_frames\frame_00136.jpg
# HI
# 0.9452160493827161
# output_frames\frame_00137.jpg
# HI
# 0.9452160493827161
# output_frames\frame_00138.jpg
# HI
# 0.8940646130728775
# output_frames\frame_00139.jpg
# output_frames\frame_00140.jpg
# output_frames\frame_00141.jpg
# hi
# 18
# output_frames\frame_00142.jpg
# output_frames\frame_00143.jpg
# output_frames\frame_00144.jpg
# output_frames\frame_00145.jpg
# output_frames\frame_00146.jpg
# hi
# 19
# output_frames\frame_00147.jpg
# output_frames\frame_00148.jpg
# output_frames\frame_00149.jpg
# output_frames\frame_00150.jpg
# output_frames\frame_00151.jpg
# output_frames\frame_00152.jpg
# hi
# 20
# output_frames\frame_00153.jpg
# output_frames\frame_00154.jpg
# hi
# 21
# output_frames\frame_00155.jpg
# output_frames\frame_00156.jpg
# output_frames\frame_00157.jpg
# output_frames\frame_00158.jpg
# output_frames\frame_00159.jpg
# output_frames\frame_00160.jpg
# output_frames\frame_00161.jpg
# output_frames\frame_00162.jpg
# output_frames\frame_00163.jpg
# output_frames\frame_00164.jpg
# output_frames\frame_00165.jpg
# output_frames\frame_00166.jpg
# output_frames\frame_00167.jpg
# output_frames\frame_00168.jpg
# output_frames\frame_00169.jpg
# hi
# 22
# output_frames\frame_00170.jpg
# output_frames\frame_00171.jpg
# output_frames\frame_00172.jpg
# output_frames\frame_00173.jpg
# output_frames\frame_00174.jpg
# output_frames\frame_00175.jpg
# output_frames\frame_00176.jpg
# output_frames\frame_00177.jpg
# output_frames\frame_00178.jpg
# output_frames\frame_00179.jpg
# output_frames\frame_00180.jpg
# output_frames\frame_00181.jpg
# output_frames\frame_00182.jpg
# hi
# 23
# output_frames\frame_00183.jpg
# HI
# 0.5664777327935223
# output_frames\frame_00184.jpg
# HI
# 0.6291647295831396
# output_frames\frame_00185.jpg
# HI
# 0.6177847113884556
# output_frames\frame_00186.jpg
# output_frames\frame_00187.jpg
# output_frames\frame_00188.jpg
# output_frames\frame_00189.jpg
# output_frames\frame_00190.jpg
# output_frames\frame_00191.jpg
# output_frames\frame_00192.jpg
# output_frames\frame_00193.jpg
# output_frames\frame_00194.jpg
# output_frames\frame_00195.jpg
# output_frames\frame_00196.jpg
# output_frames\frame_00197.jpg
# output_frames\frame_00198.jpg
# output_frames\frame_00199.jpg
# output_frames\frame_00200.jpg
# output_frames\frame_00201.jpg
# output_frames\frame_00202.jpg
# output_frames\frame_00203.jpg
# output_frames\frame_00204.jpg
# output_frames\frame_00205.jpg
# output_frames\frame_00206.jpg
# output_frames\frame_00207.jpg
# output_frames\frame_00208.jpg
# output_frames\frame_00209.jpg
# output_frames\frame_00210.jpg
# output_frames\frame_00211.jpg
# output_frames\frame_00212.jpg
# output_frames\frame_00213.jpg
# hi
# 24
# output_frames\frame_00214.jpg
# output_frames\frame_00215.jpg
# output_frames\frame_00216.jpg
# hi
# 25
# output_frames\frame_00217.jpg
# output_frames\frame_00218.jpg
# output_frames\frame_00219.jpg
# output_frames\frame_00220.jpg
# output_frames\frame_00221.jpg
# output_frames\frame_00222.jpg
# output_frames\frame_00223.jpg
# output_frames\frame_00224.jpg
# hi
# 26
# output_frames\frame_00225.jpg
# hi
# 27
# output_frames\frame_00226.jpg
# hi
# 28
# hi
# 29
# output_frames\frame_00227.jpg
# HI
# 0.5154794391643925
# HI
# 0.9301006663830994
# output_frames\frame_00228.jpg
# HI
# 0.9101598625974369
# HI
# 0.9101598625974369
# output_frames\frame_00229.jpg
# HI
# 0.9553087057607853
# HI
# 0.9553087057607853
# output_frames\frame_00230.jpg
# output_frames\frame_00231.jpg
# output_frames\frame_00232.jpg
# hi
# 30
# output_frames\frame_00233.jpg
# output_frames\frame_00234.jpg
# output_frames\frame_00235.jpg
# output_frames\frame_00236.jpg
# hi
# 31
# output_frames\frame_00237.jpg
# output_frames\frame_00238.jpg
# output_frames\frame_00239.jpg
# hi
# 32
# output_frames\frame_00240.jpg
# HI
# 0.8171428571428572
# output_frames\frame_00241.jpg
# output_frames\frame_00242.jpg
# hi
# 33
# output_frames\frame_00243.jpg
# hi
# 34
# output_frames\frame_00244.jpg
# HI
# 0.950625
# hi
# 35
# output_frames\frame_00245.jpg
# HI
# 0.9042098840756558
# HI
# 0.7782869228057807
# output_frames\frame_00246.jpg
# HI
# 0.780376497432972
# HI
# 0.838475499092559
# output_frames\frame_00247.jpg
# HI
# 0.6652078774617067
# HI
# 0.8171428571428572
# output_frames\frame_00248.jpg
# HI
# 0.8674790555978675
# hi
# 36
# output_frames\frame_00249.jpg
# HI
# 0.9137110726643599
# hi
# 37
# hi
# 38
# output_frames\frame_00250.jpg
# HI
# 0.8874186095358118
# HI
# 0.5754669358909642
# HI
# 0.5129498822737976
# output_frames\frame_00251.jpg
# HI
# 0.644398766700925
# HI
# 0.6018771998435667
# output_frames\frame_00252.jpg
# HI
# 0.7480021310602024
# HI
# 0.7851944271158245
# hi
# 39
# output_frames\frame_00253.jpg
# HI
# 0.689553702795488
# HI
# 0.7207857286029264
# output_frames\frame_00254.jpg
# HI
# 0.5740740740740741
# HI
# 0.5663235579724218
# output_frames\frame_00255.jpg
# HI
# 0.5437100213219617
# HI
# 0.5546218487394958
# hi
# 40
# output_frames\frame_00256.jpg
# HI
# 0.6865525672371638
# HI
# 0.5660809778456837
# output_frames\frame_00257.jpg
# HI
# 0.6016333938294011
# HI
# 0.6238679814852083
# hi
# 41
# output_frames\frame_00258.jpg
# HI
# 0.5971209213051824
# hi
# 42
# output_frames\frame_00259.jpg
# hi
# 43
# hi
# 44
# output_frames\frame_00260.jpg
# hi
# 45
# hi
# 46
# output_frames\frame_00261.jpg
# HI
# 0.5427415275670208
# hi
# 47
# output_frames\frame_00262.jpg
# HI
# 0.588861985472155
# hi
# 48
# output_frames\frame_00263.jpg
# HI
# 0.5655577299412916
# hi
# 49
# output_frames\frame_00264.jpg
# HI
# 0.6600938967136151
# HI
# 0.612002637942405
# hi
# 50
# output_frames\frame_00265.jpg
# HI
# 0.6694214876033058
# HI
# 0.7730147575544624
# HI
# 0.8919753086419753
# output_frames\frame_00266.jpg
# hi
# 51
# output_frames\frame_00267.jpg
# HI
# 0.9731555880204529
# hi
# 52
# output_frames\frame_00268.jpg
# HI
# 0.9731555880204529
# HI
# 0.8346288675506782
# output_frames\frame_00269.jpg
# HI
# 0.9466666666666667
# output_frames\frame_00270.jpg
# HI
# 1.0
# output_frames\frame_00271.jpg
# HI
# 0.972972972972973
# hi
# 53
# output_frames\frame_00272.jpg
# HI
# 0.9731555880204529
# HI
# 0.8130489335006273
# output_frames\frame_00273.jpg
# HI
# 0.8708979444644789
# output_frames\frame_00274.jpg
# HI
# 0.6454720616570327
# hi
# 54
# output_frames\frame_00275.jpg
# HI
# 0.7616950363052017
# output_frames\frame_00276.jpg
# HI
# 0.7854406130268199
# hi
# 55
# output_frames\frame_00277.jpg
# HI
# 0.8582243633860978
# hi
# 56
# output_frames\frame_00278.jpg
# HI
# 0.9567580625679429
# output_frames\frame_00279.jpg
# HI
# 0.9569943289224953
# output_frames\frame_00280.jpg
# HI
# 0.8959731543624161
# output_frames\frame_00281.jpg
# HI
# 1.0
# output_frames\frame_00282.jpg
# HI
# 0.9559245848420527
# hi
# 57
# output_frames\frame_00283.jpg
# HI
# 0.9350268685881779
# HI
# 0.9500080115366127
# output_frames\frame_00284.jpg
# HI
# 0.8552693208430914
# HI
# 0.9512269471117207
# hi
# 58
# output_frames\frame_00285.jpg
# HI
# 0.9329803719008265
# HI
# 0.8346288675506782
# output_frames\frame_00286.jpg
# output_frames\frame_00287.jpg
# output_frames\frame_00288.jpg
# output_frames\frame_00289.jpg
# output_frames\frame_00290.jpg
# output_frames\frame_00291.jpg
# output_frames\frame_00292.jpg
# output_frames\frame_00293.jpg
# output_frames\frame_00294.jpg
# output_frames\frame_00295.jpg
# output_frames\frame_00296.jpg
# output_frames\frame_00297.jpg
# output_frames\frame_00298.jpg
# output_frames\frame_00299.jpg
# output_frames\frame_00300.jpg
# output_frames\frame_00301.jpg
# output_frames\frame_00302.jpg
# output_frames\frame_00303.jpg
# output_frames\frame_00304.jpg
# output_frames\frame_00305.jpg
# output_frames\frame_00306.jpg
# output_frames\frame_00307.jpg
# output_frames\frame_00308.jpg
# output_frames\frame_00309.jpg
# output_frames\frame_00310.jpg
# output_frames\frame_00311.jpg
# output_frames\frame_00312.jpg
# hi
# 59
# output_frames\frame_00313.jpg
# HI
# 0.936947402387867
# output_frames\frame_00314.jpg
# HI
# 0.9088854961832061
# output_frames\frame_00315.jpg
# HI
# 0.8346982421365604
# hi
# 60
# output_frames\frame_00316.jpg
# HI
# 0.8117831585138712
# output_frames\frame_00317.jpg
# HI
# 0.9804882737408689
# output_frames\frame_00318.jpg
# HI
# 0.9259522961908152
# output_frames\frame_00319.jpg
# HI
# 0.9629629629629629
# output_frames\frame_00320.jpg
# HI
# 0.9103235218398695
# hi
# 61
# output_frames\frame_00321.jpg
# HI
# 0.9436734693877551
# output_frames\frame_00322.jpg
# output_frames\frame_00323.jpg
# output_frames\frame_00324.jpg
# output_frames\frame_00325.jpg
# output_frames\frame_00326.jpg
# output_frames\frame_00327.jpg
# output_frames\frame_00328.jpg
# output_frames\frame_00329.jpg
# output_frames\frame_00330.jpg
# output_frames\frame_00331.jpg
# output_frames\frame_00332.jpg
# output_frames\frame_00333.jpg
# output_frames\frame_00334.jpg
# output_frames\frame_00335.jpg
# output_frames\frame_00336.jpg
# hi
# 62
# output_frames\frame_00337.jpg
# output_frames\frame_00338.jpg
# output_frames\frame_00339.jpg
# output_frames\frame_00340.jpg
# output_frames\frame_00341.jpg
# output_frames\frame_00342.jpg
# output_frames\frame_00343.jpg
# output_frames\frame_00344.jpg
# hi
# 63
# output_frames\frame_00345.jpg
# HI
# 0.7631126965253006
# output_frames\frame_00346.jpg
# HI
# 0.8370549185274593
# output_frames\frame_00347.jpg
# output_frames\frame_00348.jpg
# output_frames\frame_00349.jpg
# output_frames\frame_00350.jpg
# output_frames\frame_00351.jpg
# output_frames\frame_00352.jpg
# output_frames\frame_00353.jpg
# output_frames\frame_00354.jpg
# output_frames\frame_00355.jpg
# output_frames\frame_00356.jpg
# output_frames\frame_00357.jpg
# output_frames\frame_00358.jpg
# output_frames\frame_00359.jpg
# output_frames\frame_00360.jpg
# hi
# 64
# output_frames\frame_00361.jpg
# HI
# 0.9428691451375761
# output_frames\frame_00362.jpg
# output_frames\frame_00363.jpg
# output_frames\frame_00364.jpg
# output_frames\frame_00365.jpg
# output_frames\frame_00366.jpg
# output_frames\frame_00367.jpg
# hi
# 65
# output_frames\frame_00368.jpg
# output_frames\frame_00369.jpg
# output_frames\frame_00370.jpg
# output_frames\frame_00371.jpg
# output_frames\frame_00372.jpg
# output_frames\frame_00373.jpg
# output_frames\frame_00374.jpg
# hi
# 66
# hi
# 67
# output_frames\frame_00375.jpg
# HI
# 0.8289269051321928
# output_frames\frame_00376.jpg
# HI
# 0.6625824693685203
# output_frames\frame_00377.jpg
# output_frames\frame_00378.jpg
# hi
# 68
# output_frames\frame_00379.jpg
# hi
# 69
# output_frames\frame_00380.jpg
# hi
# 70
# output_frames\frame_00381.jpg
# hi
# 71
# output_frames\frame_00382.jpg
# hi
# 72
# hi
# 73
# output_frames\frame_00383.jpg
# hi
# 74
# output_frames\frame_00384.jpg
# hi
# 75
# output_frames\frame_00385.jpg
# hi
# 76
# output_frames\frame_00386.jpg
# hi
# 77
# output_frames\frame_00387.jpg
# hi
# 78
# output_frames\frame_00388.jpg
# hi
# 79
# output_frames\frame_00389.jpg
# hi
# 80
# output_frames\frame_00390.jpg
# hi
# 81
# hi
# 82
# output_frames\frame_00391.jpg
# hi
# 83
# output_frames\frame_00392.jpg
# hi
# 84
# hi
# 85
# output_frames\frame_00393.jpg
# HI
# 0.8919753086419753
# output_frames\frame_00394.jpg
# HI
# 0.9436734693877551
# hi
# 86
# output_frames\frame_00395.jpg
# HI
# 0.8946101129838859
# hi
# 87
# output_frames\frame_00396.jpg
# HI
# 0.8726398289989312
# hi
# 88
# output_frames\frame_00397.jpg
# HI
# 0.7435897435897436
# output_frames\frame_00398.jpg
# HI
# 0.9338890485771774
# hi
# 89
# output_frames\frame_00399.jpg
# HI
# 0.9663889686871588
# HI
# 0.9452054794520548
# output_frames\frame_00400.jpg
# HI
# 0.76431829700963
# output_frames\frame_00401.jpg
# HI
# 0.5837620219190338
# hi
# 90
# output_frames\frame_00402.jpg
# HI
# 0.9205624543462382
# hi
# 91
# output_frames\frame_00403.jpg
# HI
# 0.8077231212946643
# output_frames\frame_00404.jpg
# HI
# 0.8774234898253485
# output_frames\frame_00405.jpg
# HI
# 0.8948137326515705
# output_frames\frame_00406.jpg
# output_frames\frame_00407.jpg
# hi
# 92
# output_frames\frame_00408.jpg
# output_frames\frame_00409.jpg
# hi
# 93
# output_frames\frame_00410.jpg
# output_frames\frame_00411.jpg
# output_frames\frame_00412.jpg
# output_frames\frame_00413.jpg
# output_frames\frame_00414.jpg
# output_frames\frame_00415.jpg
# output_frames\frame_00416.jpg
# output_frames\frame_00417.jpg
# output_frames\frame_00418.jpg
# output_frames\frame_00419.jpg
# output_frames\frame_00420.jpg
# output_frames\frame_00421.jpg
# output_frames\frame_00422.jpg
# output_frames\frame_00423.jpg
# output_frames\frame_00424.jpg
# output_frames\frame_00425.jpg
# output_frames\frame_00426.jpg
# output_frames\frame_00427.jpg
# output_frames\frame_00428.jpg
# output_frames\frame_00429.jpg
# output_frames\frame_00430.jpg
# output_frames\frame_00431.jpg
# output_frames\frame_00432.jpg
# output_frames\frame_00433.jpg
# output_frames\frame_00434.jpg
# output_frames\frame_00435.jpg
# output_frames\frame_00436.jpg
# output_frames\frame_00437.jpg
# output_frames\frame_00438.jpg
# output_frames\frame_00439.jpg
# output_frames\frame_00440.jpg
# output_frames\frame_00441.jpg
# output_frames\frame_00442.jpg
# output_frames\frame_00443.jpg
# output_frames\frame_00444.jpg
# output_frames\frame_00445.jpg
# output_frames\frame_00446.jpg
# output_frames\frame_00447.jpg
# output_frames\frame_00448.jpg
# hi
# 94
# output_frames\frame_00449.jpg
# HI
# 0.7831223628691983
# output_frames\frame_00450.jpg
# output_frames\frame_00451.jpg
# output_frames\frame_00452.jpg
# output_frames\frame_00453.jpg
# output_frames\frame_00454.jpg
# output_frames\frame_00455.jpg
# output_frames\frame_00456.jpg
# output_frames\frame_00457.jpg
# output_frames\frame_00458.jpg
# output_frames\frame_00459.jpg
# output_frames\frame_00460.jpg
# output_frames\frame_00461.jpg
# output_frames\frame_00462.jpg
# output_frames\frame_00463.jpg
# output_frames\frame_00464.jpg
# output_frames\frame_00465.jpg
# output_frames\frame_00466.jpg
# output_frames\frame_00467.jpg
# output_frames\frame_00468.jpg
# output_frames\frame_00469.jpg
# output_frames\frame_00470.jpg
# output_frames\frame_00471.jpg
# output_frames\frame_00472.jpg
# output_frames\frame_00473.jpg
# output_frames\frame_00474.jpg
# output_frames\frame_00475.jpg
# output_frames\frame_00476.jpg
# output_frames\frame_00477.jpg
# output_frames\frame_00478.jpg
# output_frames\frame_00479.jpg
# output_frames\frame_00480.jpg
# output_frames\frame_00481.jpg
# output_frames\frame_00482.jpg
# output_frames\frame_00483.jpg
# output_frames\frame_00484.jpg
# output_frames\frame_00485.jpg
# output_frames\frame_00486.jpg
# output_frames\frame_00487.jpg
# output_frames\frame_00488.jpg
# output_frames\frame_00489.jpg
# output_frames\frame_00490.jpg
# output_frames\frame_00491.jpg
# output_frames\frame_00492.jpg
# output_frames\frame_00493.jpg
# output_frames\frame_00494.jpg
# output_frames\frame_00495.jpg
# output_frames\frame_00496.jpg
# output_frames\frame_00497.jpg
# output_frames\frame_00498.jpg
# output_frames\frame_00499.jpg
# hi
# 95
# output_frames\frame_00500.jpg
# output_frames\frame_00501.jpg
# output_frames\frame_00502.jpg
# output_frames\frame_00503.jpg
# output_frames\frame_00504.jpg
# output_frames\frame_00505.jpg
# output_frames\frame_00506.jpg
# output_frames\frame_00507.jpg
# output_frames\frame_00508.jpg
# output_frames\frame_00509.jpg
# output_frames\frame_00510.jpg
# output_frames\frame_00511.jpg
# output_frames\frame_00512.jpg
# output_frames\frame_00513.jpg
# hi
# 96
# output_frames\frame_00514.jpg
# output_frames\frame_00515.jpg
# output_frames\frame_00516.jpg
# output_frames\frame_00517.jpg
# output_frames\frame_00518.jpg
# output_frames\frame_00519.jpg
# output_frames\frame_00520.jpg
# output_frames\frame_00521.jpg
# hi
# 97
# output_frames\frame_00522.jpg
# output_frames\frame_00523.jpg
# hi
# 98
# output_frames\frame_00524.jpg
# output_frames\frame_00525.jpg
# output_frames\frame_00526.jpg
# output_frames\frame_00527.jpg
# output_frames\frame_00528.jpg
# output_frames\frame_00529.jpg
# hi
# 99
# output_frames\frame_00530.jpg
# hi
# 100
# output_frames\frame_00531.jpg
# HI
# 0.7511045655375552
# output_frames\frame_00532.jpg
# HI
# 0.757847533632287
# output_frames\frame_00533.jpg
# output_frames\frame_00534.jpg
# output_frames\frame_00535.jpg
# output_frames\frame_00536.jpg
# output_frames\frame_00537.jpg
# output_frames\frame_00538.jpg
# hi
# 101
# hi
# 102
# output_frames\frame_00539.jpg
# hi
# 103
# output_frames\frame_00540.jpg
# output_frames\frame_00541.jpg
# hi
# 104
# hi
# 105
# output_frames\frame_00542.jpg
# hi
# 106
# output_frames\frame_00543.jpg
# output_frames\frame_00544.jpg
# output_frames\frame_00545.jpg
# output_frames\frame_00546.jpg
# hi
# 107
# hi
# 108
# output_frames\frame_00547.jpg
# hi
# 109
# output_frames\frame_00548.jpg
# HI
# 0.5290173410404624
# hi
# 110
# output_frames\frame_00549.jpg
# HI
# 0.59392575928009
# output_frames\frame_00550.jpg
# HI
# 0.7282776917974796
# output_frames\frame_00551.jpg
# HI
# 0.6976468261815305
# output_frames\frame_00552.jpg
# HI
# 0.6635320669550498
# output_frames\frame_00553.jpg
# HI
# 0.6679049034175334
# output_frames\frame_00554.jpg
# HI
# 0.8131715081575805
# output_frames\frame_00555.jpg
# HI
# 0.7928388746803069
# output_frames\frame_00556.jpg
# HI
# 0.68978305210458
# output_frames\frame_00557.jpg
# HI
# 0.7534498620055198
# output_frames\frame_00558.jpg
# HI
# 0.8474968822376626
# output_frames\frame_00559.jpg
# HI
# 0.713470143496374
# output_frames\frame_00560.jpg
# HI
# 0.6856168277430358
# output_frames\frame_00561.jpg
# HI
# 0.6513761467889908
# output_frames\frame_00562.jpg
# HI
# 0.714867617107943
# output_frames\frame_00563.jpg
# HI
# 0.8227228207639569
# output_frames\frame_00564.jpg
# HI
# 0.8117788702718972
# output_frames\frame_00565.jpg
# HI
# 0.8690430804422417
# output_frames\frame_00566.jpg
# HI
# 0.9064581791265729
# output_frames\frame_00567.jpg
# HI
# 0.7928354173707334
# output_frames\frame_00568.jpg
# HI
# 0.6378870673952641
# output_frames\frame_00569.jpg
# HI
# 0.7140004131946835
# output_frames\frame_00570.jpg
# HI
# 0.8885380274119861
# hi
# 111
# output_frames\frame_00571.jpg
# HI
# 0.937448402870388
# output_frames\frame_00572.jpg
# HI
# 0.8687022009457644
# output_frames\frame_00573.jpg
# HI
# 0.8077070447205649
# output_frames\frame_00574.jpg
# HI
# 0.7759958613554061
# output_frames\frame_00575.jpg
# HI
# 0.7827552986512524
# output_frames\frame_00576.jpg
# HI
# 0.8331292388847024
# output_frames\frame_00577.jpg
# HI
# 0.8539849034408391
# output_frames\frame_00578.jpg
# HI
# 0.9038385241023607
# output_frames\frame_00579.jpg
# HI
# 0.9584318360914106
# output_frames\frame_00580.jpg
# HI
# 0.9068293827739967
# output_frames\frame_00581.jpg
# HI
# 0.9590487514863258
# output_frames\frame_00582.jpg
# HI
# 0.9724151234567902
# output_frames\frame_00583.jpg
# HI
# 0.9596001665972511
# output_frames\frame_00584.jpg
# HI
# 0.9348570412201521
# output_frames\frame_00585.jpg
# HI
# 0.8346288675506782
# output_frames\frame_00586.jpg
# HI
# 0.8866274004112501
# output_frames\frame_00587.jpg
# HI
# 0.8458417158250077
# output_frames\frame_00588.jpg
# HI
# 0.8627958973630976
# output_frames\frame_00589.jpg
# HI
# 0.8755129958960328
# output_frames\frame_00590.jpg
# HI
# 0.8824609733700642
# output_frames\frame_00591.jpg
# HI
# 0.9618661593183886
# output_frames\frame_00592.jpg
# HI
# 0.9231064975009612
# output_frames\frame_00593.jpg
# HI
# 0.9603543941292285
# output_frames\frame_00594.jpg
# HI
# 0.9867111111111111
# output_frames\frame_00595.jpg
# HI
# 0.9606146238078418
# output_frames\frame_00596.jpg
# HI
# 0.9606596201920968
# output_frames\frame_00597.jpg
# HI
# 0.8581805863976815
# output_frames\frame_00598.jpg
# HI
# 0.8468515939628891
# output_frames\frame_00599.jpg
# HI
# 0.9012978689312611
# output_frames\frame_00600.jpg
# HI
# 0.9502766829889725
# output_frames\frame_00601.jpg
# HI
# 0.9365244536940687
# output_frames\frame_00602.jpg
# HI
# 0.9738137771774651
# output_frames\frame_00603.jpg
# HI
# 0.9606596201920968
# output_frames\frame_00604.jpg
# HI
# 0.9604403472657299
# output_frames\frame_00605.jpg
# HI
# 0.9606146238078418
# output_frames\frame_00606.jpg
# HI
# 0.9609973594216701
# output_frames\frame_00607.jpg
# HI
# 0.9477215911582826
# output_frames\frame_00608.jpg
# HI
# 0.9331297144708224
# output_frames\frame_00609.jpg
# HI
# 0.8961777777777777
# output_frames\frame_00610.jpg
# HI
# 0.9363532835632038
# output_frames\frame_00611.jpg
# HI
# 0.9743181532531736
# output_frames\frame_00612.jpg
# HI
# 0.9377369142672796
# output_frames\frame_00613.jpg
# HI
# 0.9504668460199399
# output_frames\frame_00614.jpg
# HI
# 0.9254927095016824
# output_frames\frame_00615.jpg
# HI
# 0.937319972412674
# output_frames\frame_00616.jpg
# HI
# 0.9391824526420738
# output_frames\frame_00617.jpg
# HI
# 0.963749256395003
# output_frames\frame_00618.jpg
# HI
# 0.9878420582986318
# output_frames\frame_00619.jpg
# HI
# 0.9042493131092627
# hi
# 112
# output_frames\frame_00620.jpg
# HI
# 0.9384337159930807
# output_frames\frame_00621.jpg
# HI
# 0.854752580989676
# output_frames\frame_00622.jpg
# HI
# 0.9604
# output_frames\frame_00623.jpg
# HI
# 0.923734610123119
# output_frames\frame_00624.jpg
# HI
# 0.9473777777777778
# output_frames\frame_00625.jpg
# HI
# 0.9601369307688843
# output_frames\frame_00626.jpg
# output_frames\frame_00627.jpg
# output_frames\frame_00628.jpg
# output_frames\frame_00629.jpg
# output_frames\frame_00630.jpg
# output_frames\frame_00631.jpg
# output_frames\frame_00632.jpg
# output_frames\frame_00633.jpg
# output_frames\frame_00634.jpg
# output_frames\frame_00635.jpg
# output_frames\frame_00636.jpg
# output_frames\frame_00637.jpg
# output_frames\frame_00638.jpg
# output_frames\frame_00639.jpg
# output_frames\frame_00640.jpg
# output_frames\frame_00641.jpg
# output_frames\frame_00642.jpg
# output_frames\frame_00643.jpg
# output_frames\frame_00644.jpg
# output_frames\frame_00645.jpg
# output_frames\frame_00646.jpg
# output_frames\frame_00647.jpg
# output_frames\frame_00648.jpg
# output_frames\frame_00649.jpg
# output_frames\frame_00650.jpg
# output_frames\frame_00651.jpg
# output_frames\frame_00652.jpg
# output_frames\frame_00653.jpg
# output_frames\frame_00654.jpg
# output_frames\frame_00655.jpg
# output_frames\frame_00656.jpg
# output_frames\frame_00657.jpg
# output_frames\frame_00658.jpg
# output_frames\frame_00659.jpg
# output_frames\frame_00660.jpg
# output_frames\frame_00661.jpg
# output_frames\frame_00662.jpg
# output_frames\frame_00663.jpg
# output_frames\frame_00664.jpg
# output_frames\frame_00665.jpg
# output_frames\frame_00666.jpg
# output_frames\frame_00667.jpg
# output_frames\frame_00668.jpg
# output_frames\frame_00669.jpg
# hi
# 113
# output_frames\frame_00670.jpg
# output_frames\frame_00671.jpg
# output_frames\frame_00672.jpg
# output_frames\frame_00673.jpg
# output_frames\frame_00674.jpg
# output_frames\frame_00675.jpg
# output_frames\frame_00676.jpg
# output_frames\frame_00677.jpg
# output_frames\frame_00678.jpg
# output_frames\frame_00679.jpg
# output_frames\frame_00680.jpg
# output_frames\frame_00681.jpg
# output_frames\frame_00682.jpg
# output_frames\frame_00683.jpg
# output_frames\frame_00684.jpg
# output_frames\frame_00685.jpg
# output_frames\frame_00686.jpg
# output_frames\frame_00687.jpg
# output_frames\frame_00688.jpg
# output_frames\frame_00689.jpg
# output_frames\frame_00690.jpg
# output_frames\frame_00691.jpg
# output_frames\frame_00692.jpg
# output_frames\frame_00693.jpg
# output_frames\frame_00694.jpg
# output_frames\frame_00695.jpg
# hi
# 114
# output_frames\frame_00696.jpg
# output_frames\frame_00697.jpg
# output_frames\frame_00698.jpg
# output_frames\frame_00699.jpg
# output_frames\frame_00700.jpg
# output_frames\frame_00701.jpg
# output_frames\frame_00702.jpg
# hi
# 115
# output_frames\frame_00703.jpg
# HI
# 0.8021390374331551
# output_frames\frame_00704.jpg
# HI
# 0.7046915167095116
# output_frames\frame_00705.jpg
# HI
# 0.6154080389768575
# output_frames\frame_00706.jpg
# HI
# 0.6336
# output_frames\frame_00707.jpg
# HI
# 0.7190354402630618
# output_frames\frame_00708.jpg
# output_frames\frame_00709.jpg
# output_frames\frame_00710.jpg
# output_frames\frame_00711.jpg
# output_frames\frame_00712.jpg
# output_frames\frame_00713.jpg
# output_frames\frame_00714.jpg
# output_frames\frame_00715.jpg
# output_frames\frame_00716.jpg
# output_frames\frame_00717.jpg
# output_frames\frame_00718.jpg
# hi
# 116

# %%
print(unique_tracks)
# Out:
# {0: [(1, (226, 213, 131, 131)), (2, (215, 211, 130, 130)), (3, (218, 213, 131, 131))], 1: [(8, (500, 164, 57, 57))], 2: [(9, (225, 213, 130, 130))], 4: [(12, (534, 176, 46, 46))], 5: [(16, (544, 148, 66, 66))], 6: [(21, (404, 90, 141, 141))], 7: [(23, (508, 147, 70, 70))], 8: [(27, (272, 322, 52, 52))], 3: [(11, (228, 213, 128, 128)), (12, (230, 217, 123, 123)), (13, (234, 217, 121, 121)), (14, (228, 214, 123, 123)), (15, (237, 217, 120, 120)), (16, (229, 217, 119, 119)), (17, (230, 217, 119, 119)), (18, (228, 217, 121, 121)), (19, (233, 216, 123, 123)), (20, (222, 211, 129, 129)), (21, (217, 209, 131, 131)), (22, (206, 204, 140, 140)), (23, (190, 211, 128, 128)), (24, (177, 210, 129, 129)), (25, (168, 214, 127, 127)), (26, (159, 212, 130, 130)), (27, (157, 214, 127, 127)), (28, (148, 211, 131, 131)), (29, (143, 210, 131, 131)), (30, (141, 210, 127, 127)), (31, (134, 207, 133, 133)), (32, (133, 209, 129, 129)), (33, (130, 211, 127, 127)), (34, (130, 212, 127, 127)), (35, (126, 210, 131, 131)), (36, (126, 213, 126, 126)), (37, (123, 210, 131, 131)), (38, (120, 209, 132, 132)), (39, (119, 210, 130, 130)), (40, (115, 211, 131, 131)), (41, (111, 211, 131, 131)), (42, (108, 211, 129, 129)), (43, (104, 210, 128, 128)), (44, (99, 210, 129, 129)), (45, (95, 211, 127, 127)), (46, (91, 210, 128, 128)), (47, (85, 209, 129, 129)), (48, (81, 210, 128, 128))], 11: [(88, (714, 342, 61, 61)), (89, (723, 341, 67, 67)), (90, (733, 340, 70, 70)), (91, (737, 338, 76, 76)), (92, (738, 333, 84, 84))], 12: [(106, (498, 319, 47, 47))], 9: [(78, (51, 203, 132, 132)), (79, (48, 204, 131, 131)), (80, (41, 203, 133, 133)), (81, (37, 204, 132, 132)), (82, (33, 204, 131, 131)), (83, (29, 206, 130, 130)), (84, (24, 205, 132, 132)), (85, (20, 205, 132, 132)), (86, (17, 207, 129, 129)), (87, (16, 209, 127, 127)), (88, (13, 209, 128, 128)), (89, (13, 212, 125, 125)), (90, (13, 213, 125, 125)), (91, (12, 216, 125, 125)), (92, (11, 214, 126, 126)), (93, (11, 214, 126, 126)), (94, (12, 215, 124, 124)), (95, (10, 213, 127, 127)), (96, (11, 213, 125, 125)), (97, (11, 215, 122, 122)), (98, (9, 215, 126, 126)), (99, (9, 217, 121, 121)), (100, (7, 219, 121, 121)), (101, (7, 219, 120, 120)), (102, (6, 220, 121, 121)), (103, (6, 223, 118, 118)), (104, (6, 224, 117, 117)), (105, (5, 225, 116, 116)), (106, (3, 227, 119, 119)), (107, (4, 229, 113, 113)), (108, (2, 232, 117, 117)), (109, (2, 230, 118, 118)), (110, (5, 226, 124, 124)), (111, (13, 222, 125, 125)), (112, (20, 220, 128, 128)), (113, (25, 219, 131, 131)), (114, (29, 219, 129, 129)), (115, (36, 213, 135, 135))], 10: [(81, (669, 117, 175, 175)), (82, (658, 111, 170, 170)), (83, (651, 110, 161, 161)), (84, (647, 109, 158, 158)), (85, (641, 110, 159, 159)), (86, (638, 114, 160, 160)), (87, (629, 116, 167, 167)), (88, (621, 118, 173, 173)), (89, (614, 117, 177, 177)), (90, (613, 116, 177, 177)), (91, (609, 115, 177, 177)), (92, (602, 111, 180, 180)), (93, (598, 110, 176, 176)), (94, (592, 108, 176, 176)), (95, (586, 107, 174, 174)), (96, (581, 108, 174, 174)), (97, (572, 108, 175, 175)), (98, (564, 107, 169, 169)), (99, (557, 106, 164, 164)), (100, (547, 105, 169, 169)), (101, (543, 107, 165, 165)), (102, (541, 109, 160, 160)), (103, (536, 110, 165, 165)), (104, (532, 109, 166, 166)), (105, (531, 110, 164, 164)), (106, (533, 112, 161, 161)), (107, (534, 116, 157, 157)), (108, (529, 118, 157, 157)), (109, (524, 114, 156, 156)), (110, (525, 110, 149, 149)), (111, (535, 95, 150, 150)), (112, (564, 89, 140, 140)), (113, (590, 97, 126, 126)), (114, (599, 110, 122, 122)), (115, (597, 121, 117, 117)), (116, (591, 128, 116, 116)), (117, (585, 132, 116, 116)), (118, (577, 132, 122, 122)), (119, (576, 146, 116, 116)), (120, (563, 143, 125, 125)), (121, (549, 146, 136, 136)), (122, (541, 152, 139, 139)), (123, (533, 158, 141, 141)), (124, (529, 168, 138, 138)), (125, (522, 180, 138, 138))], 13: [(126, (406, 83, 36, 36))], 14: [(128, (258, 98, 34, 34)), (129, (252, 96, 33, 33)), (130, (246, 97, 34, 34))], 15: [(132, (239, 97, 34 ...

# %%
def draw_bbox_and_id(frame, bbox, track_id):
    x, y, w, h = bbox
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(frame, f'Track ID: {track_id}', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    return frame

# %%
input_folder = "output_frames/"
output_folder = "output_frames_with_faces_with_tracking/"
file_count = len([name for name in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, name))])
file_dict = {i: 0 for i in range(file_count)}
for track_id, bboxes in unique_tracks.items():
    for frame_number, bbox in bboxes:
        if file_dict[frame_number]==0:
            frame_path = f"{input_folder}frame_{frame_number:05d}.jpg"
            file_dict[frame_number] += 1
        else:
            frame_path = f"{output_folder}frame_{frame_number:05d}.jpg"
        frame = cv2.imread(frame_path)
        frame = draw_bbox_and_id(frame, bbox, track_id)
        output_path = f"{output_folder}frame_{frame_number:05d}.jpg"
        cv2.imwrite(output_path, frame)
print("All frames processed and saved.")
# Out:
# All frames processed and saved.

# %%
folder_with_faces = 'output_frames_with_faces_with_tracking'
source_folder = 'output_frames'
faces_files = os.listdir(folder_with_faces)
source_files = os.listdir(source_folder)
for file in source_files:
    if file not in faces_files:
        source_path = os.path.join(source_folder, file)
        destination_path = os.path.join(folder_with_faces, file)
        shutil.copyfile(source_path, destination_path)

# %%
frames_folder = "output_frames_with_faces_with_tracking"
output_video_path = "output_video_tracking.mp4"
frames_to_video(frames_folder, output_video_path)
# Out:
# Video saved successfully at 'output_video_tracking.mp4'

# %% [markdown]
# Some of the face tracks are good but the others are bad.
#
# We observe that many people are being tracked in a single frame.
#
# We also notice that some of the detections are random and do not correspond to faces.
#
# Yes, a unique person is associated to the same track only if it's detected in each of the frames. Otherwise we will have to use other techniques like kalman filters for the same.

# %%
import os
import shutil
import random

original_train_images_dir = "archive/images/train/"
original_val_images_dir = "archive/images/val/"
original_train_labels_dir = "archive/labels/train/"
original_val_labels_dir = "archive/labels/val/"

new_train_images_dir = "new_dataset/images/train/"
new_val_images_dir = "new_dataset/images/val/"
new_train_labels_dir = "new_dataset/labels/train/"
new_val_labels_dir = "new_dataset/labels/val/"

os.makedirs(new_train_images_dir, exist_ok=True)
os.makedirs(new_val_images_dir, exist_ok=True)
os.makedirs(new_train_labels_dir, exist_ok=True)
os.makedirs(new_val_labels_dir, exist_ok=True)

selected_images = random.sample(os.listdir(original_train_images_dir), 100)

for image in selected_images:
    src_image = os.path.join(original_train_images_dir, image)
    dest_image = os.path.join(new_train_images_dir, image)
    shutil.copy(src_image, dest_image)

    label_filename = os.path.splitext(image)[0] + ".txt"
    src_label = os.path.join(original_train_labels_dir, label_filename)
    dest_label = os.path.join(new_train_labels_dir, label_filename)
    shutil.copy(src_label, dest_label)

for file_name in os.listdir(original_val_images_dir):
    src_val_image = os.path.join(original_val_images_dir, file_name)
    dest_val_image = os.path.join(new_val_images_dir, file_name)
    shutil.copy(src_val_image, dest_val_image)

    label_filename = os.path.splitext(file_name)[0] + ".txt"
    src_val_label = os.path.join(original_val_labels_dir, label_filename)
    dest_val_label = os.path.join(new_val_labels_dir, label_filename)
    shutil.copy(src_val_label, dest_val_label)
# Out:
# New dataset created with 100 images in the training set.

# %% [markdown]
# The link for the output video is: https://iiitaphyd-my.sharepoint.com/:v:/g/personal/harshit_aggarwal_research_iiit_ac_in/ETUhPau-81ZNtBG9zGKU2vIBH_J--7ZkymX8kbEGtv9b8g?nav=eyJyZWZlcnJhbEluZm8iOnsicmVmZXJyYWxBcHAiOiJPbmVEcml2ZUZvckJ1c2luZXNzIiwicmVmZXJyYWxBcHBQbGF0Zm9ybSI6IldlYiIsInJlZmVycmFsTW9kZSI6InZpZXciLCJyZWZlcnJhbFZpZXciOiJNeUZpbGVzTGlua0NvcHkifX0&e=CpEPJ2
